# %%
import pandas as pd
import matplotlib.pyplot as plt

def get_max_close(symbol):
    df = pd.read_csv('data/{}.csv'.format(symbol))
    print(df)
    df[['Close','Adj Close']].plot()
    plt.ylabel('Close')
    plt.xlabel('Days')
    plt.show()  # must be closed to show plot
    return df['Close'].max()
                     
def test_run():
    for symbol in ['AAPL', 'IBM']:
        print("Max close")
        print(symbol, get_max_close(symbol))
                     
if __name__ == "__main__":  # if run standalone
    test_run()
# Out:
# Max close
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-11-04   64.332497   64.462502   63.845001   64.375000   63.742554
# 1    2019-11-05   64.262497   64.547501   64.080002   64.282501   63.650970
# 2    2019-11-06   64.192497   64.372498   63.842499   64.309998   63.678192
# 3    2019-11-07   64.684998   65.087502   64.527496   64.857498   64.413116
# 4    2019-11-08   64.672501   65.110001   64.212502   65.035004   64.589409
# ..          ...         ...         ...         ...         ...         ...
# 248  2020-10-28  115.050003  115.430000  111.099998  111.199997  111.199997
# 249  2020-10-29  112.370003  116.930000  112.199997  115.320000  115.320000
# 250  2020-10-30  111.059998  111.989998  107.720001  108.860001  108.860001
# 251  2020-11-02  109.110001  110.680000  107.320000  108.769997  108.769997
# 252  2020-11-03  109.660004  111.459999  108.730003  110.440002  110.440002
#
#         Volume
# 0    103272000
# 1     79897600
# 2     75864400
# 3     94940400
# 4     69986400
# ..         ...
# 248  143937800
# 249  146129200
# 250  190272600
# 251  122515100
# 252  104027423
#
# [253 rows x 7 columns]
# AAPL 134.179993
# Max close
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-11-04  136.240005  137.740005  136.229996  137.669998  131.157547
# 1    2019-11-05  137.800003  138.759995  137.630005  137.889999  131.367126
# 2    2019-11-06  138.000000  138.779999  137.550003  138.779999  132.215042
# 3    2019-11-07  137.869995  139.139999  137.580002  137.690002  132.725922
# 4    2019-11-08  137.580002  137.610001  136.160004  137.610001  132.648804
# ..          ...         ...         ...         ...         ...         ...
# 248  2020-10-28  108.660004  109.730003  105.919998  106.650002  106.650002
# 249  2020-10-29  107.250000  109.639999  106.550003  108.910004  108.910004
# 250  2020-10-30  107.900002  111.800003  107.750000  111.660004  111.660004
# 251  2020-11-02  112.650002  113.830002  112.250000  112.910004  112.910004
# 252  2020-11-03  114.000000  115.650002  113.629997  114.160004  114.160004
#
#       Volume
# 0    3335400
# 1    3015000
# 2    4477300
# 3    4073800
# 4    2278400
# ..       ...
# 248  9427300
# 249  6760200
# 250  7921500
# 251  5310400
# 252  4147962
#
# [253 rows x 7 columns]
# IBM 156.759995
